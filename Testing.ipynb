# %%
import torch

# %%
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %%
from transformers import AutoTokenizer

# Load a tokenizer for a pre-trained model (e.g., 'bert-base-uncased')
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

# Tokenize a sentence
text = "Hello, this is a test sentence bomb for AutoTokenizer."
encoded_input = tokenizer(text, padding=True, truncation=True, return_tensors='pt')

# encoded_input will contain 'input_ids', 'attention_mask', and 'token_type_ids' (if applicable) as PyTorch tensors
print(encoded_input['input_ids'])
# Out:
# tensor([[  101,  7592,  1010,  2023,  2003,  1037,  3231,  6251,  5968,  2005,
#           8285, 18715, 18595,  6290,  1012,   102]])

# %%
import sentencepiece as spm
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 2
#       1 import sentencepiece as spm
# ----> 2 sp = spm.SentencePieceProcessor(model_file='test/test_model.model')
#
# File ~/Computer_Science/Mygpt/venv/lib/python3.12/site-packages/sentencepiece/__init__.py:468, in SentencePieceProcessor.Init(self, model_file, model_proto, out_type, add_bos, add_eos, reverse, emit_unk_piece, enable_sampling, nbest_size, alpha, num_threads)
#     466 self._num_threads = num_threads
#     467 if model_file or model_proto:
# --> 468   self.Load(model_file=model_file, model_proto=model_proto)
#
# File ~/Computer_Science/Mygpt/venv/lib/python3.12/site-packages/sentencepiece/__init__.py:961, in SentencePieceProcessor.Load(self, model_file, model_proto)
#     959 if model_proto:
#     960   return self.LoadFromSerializedProto(model_proto)
# ...

# %%
import tiktoken

# %%
enc=tiktoken.get_encoding("cl100k_base")
tokens=enc.encode_ordinary("Hello, this is a test sentence bomb for AutoTokenizer.")
print(tokens)
# Out:
# [9906, 11, 420, 374, 264, 1296, 11914, 13054, 369, 9156, 38534, 13]

# %%
enc.n_vocab
# Out:
# 100277
